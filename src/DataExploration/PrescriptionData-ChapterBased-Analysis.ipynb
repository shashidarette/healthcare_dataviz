# %% [markdown]
# ### Analysis of Prescription costs based on below categories
# * 0601021* Oral hypoglycaemics
# * 0601022* Metformin
# * 0601023* Gliptins
# * 0601011* Insulin
# * 0601012*Insulin
# * 0704050* Viagra and others

# %%
import pandas as pd
presDec17 = pd.read_csv('./T201712PDPI+BNFT.CSV', sep=',', encoding = "ISO-8859-1")
print(type(presDec17))
presDec17.head(15)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#     SHA  PCT PRACTICE         BNF CODE  \
# 0   Q44  RTV   Y04937  0401010Z0AAAAAA
# 1   Q44  RTV   Y04937  0401010Z0AAACAC
# 2   Q44  RTV   Y04937  0401020K0AAAHAH
# 3   Q44  RTV   Y04937  0401020P0AAABAB
# 4   Q44  RTV   Y04937  0402010ABAAABAB
# 5   Q44  RTV   Y04937  0402010ABAAAVAV
# 6   Q44  RTV   Y04937  0402010ABAAAWAW
# 7   Q44  RTV   Y04937  0402010ABAAAXAX
# 8   Q44  RTV   Y04937  0402010D0AAAIAI
# 9   Q44  RTV   Y04937  040201060AAACAC
# 10  Q44  RTV   Y04937  040201060AAALAL
# 11  Q44  RTV   Y04937  0402030K0BFABAI
# 12  Q44  RTV   Y04937  0403010R0AAAAAA
# 13  Q44  RTV   Y04937  0403030D0AAAAAA
# 14  Q44  RTV   Y04937  0403030Q0AAAAAA
#
#    BNF NAME                                      ITEMS    NIC          \
# 0      Zopiclone_Tab 7.5mg                             1         0.47
# 1      Zopiclone_Tab 3.75mg                            1         0.46
# 2      Diazepam_Tab 2mg                                4         1.62
# 3      Lorazepam_Tab 1mg                               2         0.71
# 4      Quetiapine_Tab 25mg                             1         8.44
# 5      Quetiapine_Tab 50mg M/R                         1        15.79
# 6      Quetiapine_Tab 200mg M/R                        1        26.39
# 7      Quetiapine_Tab 300mg M/R                        1       158.67
# 8      Chlorpromazine HCl_Tab 25mg                     3        71.49
# 9      Olanzapine_Tab 10mg                             2        33.99
# 10     Olanzapine_Tab 15mg                             1         7.58
# 11     Priadel_Tab 200mg                               1         0.77
# 12     Lofepramine HCl_Tab 70mg                        1         2.36
# 13     Citalopram Hydrob_Tab 20mg                      1         0.07
# 14     Sertraline HCl_Tab 50mg                         4         2.01
#
#     ACT COST     QUANTITY  PERIOD
# 0          0.55        14  201712
# 1          0.54        14  201712
# 2          1.96        69  201712
# 3          0.88         5  201712
# 4          7.93        42  201712
# 5         14.74        14  201712
# 6         24.56        14  201712
# 7        147.09        56  201712
# 8         66.46        63  201712
# 9         31.61        35  201712
# 10         7.13         7  201712
# 11         0.83        28  201712
# 12         2.30        14  201712
# 13         0.18         1  201712
# 14         2.22        63  201712

# %%
presDec17.describe()
# Out:
#             ITEMS     NIC           ACT COST         QUANTITY     PERIOD
# count  9.818208e+06  9.818208e+06  9.818208e+06  9.818208e+06  9818208.0
# mean   9.378867e+00  7.466316e+01  6.950550e+01  7.268416e+02   201712.0
# std    3.146270e+01  2.020389e+02  1.875285e+02  4.148579e+03        0.0
# min    1.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00   201712.0
# 25%    1.000000e+00  8.230000e+00  7.720000e+00  2.800000e+01   201712.0
# 50%    2.000000e+00  2.364000e+01  2.212000e+01  1.000000e+02   201712.0
# 75%    6.000000e+00  6.635000e+01  6.177000e+01  3.360000e+02   201712.0
# max    6.436000e+03  4.241324e+04  3.928655e+04  2.423407e+06   201712.0

# %%
# UPDATE CHAPTER NUMBER - BASED ON MEDICINES OF INTRESET
presDec17['CHAPTER'] = presDec17['BNF CODE'].str[:2]
presDec17.head()
# Out:
#    SHA  PCT PRACTICE         BNF CODE  \
# 0  Q44  RTV   Y04937  0401010Z0AAAAAA
# 1  Q44  RTV   Y04937  0401010Z0AAACAC
# 2  Q44  RTV   Y04937  0401020K0AAAHAH
# 3  Q44  RTV   Y04937  0401020P0AAABAB
# 4  Q44  RTV   Y04937  0402010ABAAABAB
#
#   BNF NAME                                      ITEMS    NIC          \
# 0     Zopiclone_Tab 7.5mg                             1         0.47
# 1     Zopiclone_Tab 3.75mg                            1         0.46
# 2     Diazepam_Tab 2mg                                4         1.62
# 3     Lorazepam_Tab 1mg                               2         0.71
# 4     Quetiapine_Tab 25mg                             1         8.44
#
#    ACT COST     QUANTITY  PERIOD                     CHAPTER
# 0         0.55        14  201712                          04
# 1         0.54        14  201712                          04
# 2         1.96        69  201712                          04
# 3         0.88         5  201712                          04
# 4         7.93        42  201712                          04

# %%
# UPDATE SUB-CHAPTER NUMBER - 2 characters of BNF CODE
presDec17['SUB_CHAPTER'] = presDec17['BNF CODE'].str[:7]
presDec17.head()
# Out:
#    SHA  PCT PRACTICE         BNF CODE  \
# 0  Q44  RTV   Y04937  0401010Z0AAAAAA
# 1  Q44  RTV   Y04937  0401010Z0AAACAC
# 2  Q44  RTV   Y04937  0401020K0AAAHAH
# 3  Q44  RTV   Y04937  0401020P0AAABAB
# 4  Q44  RTV   Y04937  0402010ABAAABAB
#
#   BNF NAME                                      ITEMS    NIC          \
# 0     Zopiclone_Tab 7.5mg                             1         0.47
# 1     Zopiclone_Tab 3.75mg                            1         0.46
# 2     Diazepam_Tab 2mg                                4         1.62
# 3     Lorazepam_Tab 1mg                               2         0.71
# 4     Quetiapine_Tab 25mg                             1         8.44
#
#    ACT COST     QUANTITY  PERIOD                     CHAPTER SUB_CHAPTER
# 0         0.55        14  201712                          04     0401010
# 1         0.54        14  201712                          04     0401010
# 2         1.96        69  201712                          04     0401020
# 3         0.88         5  201712                          04     0401020
# 4         7.93        42  201712                          04     0402010

# %%
# UPDATE SUB-CHAPTER NUMBER - 2 characters of BNF CODE
presDec17['SUB_CHAPTER_REM'] = presDec17['BNF CODE'].str[7:]
presDec17.head()
# Out:
#    SHA  PCT PRACTICE         BNF CODE  \
# 0  Q44  RTV   Y04937  0401010Z0AAAAAA
# 1  Q44  RTV   Y04937  0401010Z0AAACAC
# 2  Q44  RTV   Y04937  0401020K0AAAHAH
# 3  Q44  RTV   Y04937  0401020P0AAABAB
# 4  Q44  RTV   Y04937  0402010ABAAABAB
#
#   BNF NAME                                      ITEMS    NIC          \
# 0     Zopiclone_Tab 7.5mg                             1         0.47
# 1     Zopiclone_Tab 3.75mg                            1         0.46
# 2     Diazepam_Tab 2mg                                4         1.62
# 3     Lorazepam_Tab 1mg                               2         0.71
# 4     Quetiapine_Tab 25mg                             1         8.44
#
#    ACT COST     QUANTITY  PERIOD                     CHAPTER SUB_CHAPTER  \
# 0         0.55        14  201712                          04     0401010
# 1         0.54        14  201712                          04     0401010
# 2         1.96        69  201712                          04     0401020
# 3         0.88         5  201712                          04     0401020
# 4         7.93        42  201712                          04     0402010
#
#   SUB_CHAPTER_REM
# 0        Z0AAAAAA
# 1        Z0AAACAC
# 2        K0AAAHAH
# 3        P0AAABAB
# 4        ABAAABAB

# %%
# GROUP the prescription data by Practice code and Sub_Chapter
PracticeBySubChapter = presDec17.groupby(['PRACTICE', 'SUB_CHAPTER'])
PracticeBySubChapter.head(15)
# Out:
#          SHA  PCT PRACTICE         BNF CODE  \
# 0        Q44  RTV   Y04937  0401010Z0AAAAAA
# 1        Q44  RTV   Y04937  0401010Z0AAACAC
# 2        Q44  RTV   Y04937  0401020K0AAAHAH
# 3        Q44  RTV   Y04937  0401020P0AAABAB
# 4        Q44  RTV   Y04937  0402010ABAAABAB
# 5        Q44  RTV   Y04937  0402010ABAAAVAV
# 6        Q44  RTV   Y04937  0402010ABAAAWAW
# 7        Q44  RTV   Y04937  0402010ABAAAXAX
# 8        Q44  RTV   Y04937  0402010D0AAAIAI
# 9        Q44  RTV   Y04937  040201060AAACAC
# 10       Q44  RTV   Y04937  040201060AAALAL
# 11       Q44  RTV   Y04937  0402030K0BFABAI
# 12       Q44  RTV   Y04937  0403010R0AAAAAA
# 13       Q44  RTV   Y04937  0403030D0AAAAAA
# 14       Q44  RTV   Y04937  0403030Q0AAAAAA
# 15       Q44  RTV   Y04937  0403030Q0AAABAB
# 16       Q44  RTV   Y04937  0403030X0AAACAC
# 17       Q44  RTV   Y04937  0403040X0AAAAAA
# 18       Q44  RTV   Y04937  0403040X0AAANAN
# 19       Q44  RTV   Y04937  0403040Y0AAABAB
# 20       Q44  RTV   Y04937  0408010AEAAACAC
# 21       Q44  RTV   Y04937  0408010AEAAAEAE
# 22       Q44  RTV   Y05294  0204000R0AAAHAH
# 23       Q44  RTV   Y05294  0204000R0AAAJAJ
# 24       Q44  RTV   Y05294  0304010W0AAALAL
# 25       Q44  RTV   Y05294  0401010R0AAACAC
# 26       Q44  RTV   Y05294  0401010Z0AAAAAA
# 27       Q44  RTV   Y05294  0401010Z0AAACAC
# 28       Q44  RTV   Y05294  0401020B0AAAAAA
# 29       Q44  RTV   Y05294  0401020K0AAAHAH
# ...      ...  ...      ...              ...
# 9818178  Q70  99M   Y00617  21010230102
# 9818179  Q70  99M   Y00617  21010230111
# 9818180  Q70  99M   Y00617  21010230115
# 9818181  Q70  99M   Y00617  21010230116
# 9818182  Q70  99M   Y00617  21012500100
# 9818183  Q70  99M   Y00617  21120000130
# 9818184  Q70  99M   Y00617  21220000214
# 9818185  Q70  99M   Y00617  21240000105
# 9818186  Q70  99M   Y00617  21240000120
# 9818187  Q70  99M   Y00617  21300000104
# 9818188  Q70  99M   Y00617  23802098001
# 9818189  Q70  99M   Y03585  0201010F0AAAEAE
# 9818190  Q70  99M   Y03585  0203020D0AAAAAA
# 9818191  Q70  99M   Y03585  0203020D0AAABAB
# 9818192  Q70  99M   Y03585  0401010T0AAAMAM
# 9818193  Q70  99M   Y03585  0403030X0AAAAAA
# 9818194  Q70  99M   Y03585  0703010E0AAACAC
# 9818195  Q70  99M   Y03585  1001010P0AAAEAE
# 9818196  Q70  99M   Y03585  1001040C0AAAAAA
# 9818197  Q70  99M   Y04164  0407010H0AAAWAW
# 9818198  Q70  99M   Y04164  0502030B0AAABAB
# 9818199  Q70  99M   Y04164  130201000BBAEA3
# 9818200  Q70  99M   Y04164  130201000BBDPBX
# 9818201  Q70  99M   Y04164  1302011L0BFAAAE
# 9818202  Q70  99M   Y04164  1310020H0AAABAB
# 9818203  Q70  99M   Y04164  1310020N0AAAAAA
# 9818204  Q70  99M   Y04164  21220000204
# 9818205  Q70  99M   Y04164  21220000211
# 9818206  Q70  99M   Y04164  21220000217
# 9818207  Q70  99M   Y04164  21220000235
#
#         BNF NAME                                      ITEMS    NIC          \
# 0           Zopiclone_Tab 7.5mg                             1         0.47
# 1           Zopiclone_Tab 3.75mg                            1         0.46
# 2           Diazepam_Tab 2mg                                4         1.62
# 3           Lorazepam_Tab 1mg                               2         0.71
# 4           Quetiapine_Tab 25mg                             1         8.44
# 5           Quetiapine_Tab 50mg M/R                         1        15.79
# 6           Quetiapine_Tab 200mg M/R                        1        26.39
# 7           Quetiapine_Tab 300mg M/R                        1       158.67
# 8           Chlorpromazine HCl_Tab 25mg                     3        71.49
# 9           Olanzapine_Tab 10mg                             2        33.99
# 10          Olanzapine_Tab 15mg                             1         7.58
# 11          Priadel_Tab 200mg                               1         0.77
# 12          Lofepramine HCl_Tab 70mg                        1         2.36
# 13          Citalopram Hydrob_Tab 20mg                      1         0.07
# 14          Sertraline HCl_Tab 50mg                         4         2.01
# 15          Sertraline HCl_Tab 100mg                        3         1.86
# 16          Escitalopram_Tab 5mg                            1         0.68
# 17          Mirtazapine_Tab 30mg                            2         1.83
# 18          Mirtazapine_Tab 15mg                            6        11.36
# 19          Duloxetine HCl_Cap G/R 60mg                     1        29.14
# 20          Pregabalin_Cap 75mg                             1         2.26
# 21          Pregabalin_Cap 150mg                            1         3.66
# 22          Propranolol HCl_Tab 10mg                        1         1.62
# 23          Propranolol HCl_Tab 40mg                       14         7.04
# 24          Promethazine HCl_Tab 25mg                       3         2.90
# 25          Nitrazepam_Tab 5mg                             11         4.01
# 26          Zopiclone_Tab 7.5mg                            42        15.16
# 27          Zopiclone_Tab 3.75mg                           16         4.60
# 28          Buspirone HCl_Tab 5mg                           2        23.24
# 29          Diazepam_Tab 2mg                               12         6.01
# ...                                              ...      ...          ...
# 9818178     Volumatic                                       2         7.76
# 9818179     Volumatic Paed + Mask                           4        27.32
# 9818180     Aerochamber Plus                                7        34.30
# 9818181     Aerochamber Plus + Adult/Child/Infant Ma       15       122.55
# 9818182     T & R Sod Bicarb Ear Dps 5% Ear Wax Soft        3         3.75
# 9818183     Clement Clarke Stnd Range Peak Flow Mete        1         7.08
# 9818184     Zerobase Crm (Appl)                             2         6.30
# 9818185     Mandanol Sod Chlor 0.9% Nsl Dps                 2         1.98
# 9818186     Almus Sod Chlor 0.9% Nsl Dps                    2         1.98
# 9818187     Hylo-Tear Sod Hyaluronate Eye Dps 0.1% P        1        17.00
# 9818188     H & R_Proshield Plus Skin Prote 115g            1         9.94
# 9818189     Digoxin_Tab 125mcg                              1         2.94
# 9818190     Amiodarone HCl_Tab 100mg                        1         3.26
# 9818191     Amiodarone HCl_Tab 200mg                        2        10.10
# 9818192     Temazepam_Tab 10mg                              1         0.53
# 9818193     Escitalopram_Tab 10mg                           1         2.30
# 9818194     Ethinylestr/Gestodene_Tab 20mcg/75mcg           1        17.70
# 9818195     Naproxen_Tab 500mg                              1         2.28
# 9818196     Allopurinol_Tab 100mg                           1         1.38
# 9818197     Paracet_Oral Susp Paed 120mg/5ml S/F            1         1.19
# 9818198     Nystatin_Oral Susp 100 000u/ml                  1         3.72
# 9818199     Diprobase_Oint                                  1         5.99
# 9818200     Neutrogena_Norwegian For Dermat Crm             2        12.00
# 9818201     Cetraben_Bath Oil                               2        17.25
# 9818202     Clotrimazole_Crm 1%                             1         0.97
# 9818203     Miconazole Nit_Crm 2%                           1         1.82
# 9818204     Zeroderm Oint                                   1         2.41
# 9818205     QV Gentle Wsh                                   1         3.17
# 9818206     Zeroneum Bath Add                               1         4.48
# 9818207     Cetraben Crm 500g                               1         5.99
#
#          ACT COST     QUANTITY  PERIOD                     CHAPTER SUB_CHAPTER
# 0               0.55        14  201712                          04     0401010
# 1               0.54        14  201712                          04     0401010
# 2               1.96        69  201712                          04     0401020
# 3               0.88         5  201712                          04     0401020
# 4               7.93        42  201712                          04     0402010
# 5              14.74        14  201712                          04     0402010
# 6              24.56        14  201712                          04     0402010
# 7             147.09        56  201712                          04     0402010
# 8              66.46        63  201712                          04     0402010
# 9              31.61        35  201712                          04     0402010
# 10              7.13         7  201712                          04     0402010
# 11              0.83        28  201712                          04     0402030
# 12              2.30        14  201712                          04     0403010
# 13              0.18         1  201712                          04     0403030
# 14              2.22        63  201712                          04     0403030
# 15              2.05        49  201712                          04     0403030
# 16              0.74        21  201712                          04     0403030
# 17              1.82        42  201712                          04     0403040
# 18             11.09       112  201712                          04     0403040
# 19             27.00        56  201712                          04     0403040
# 20              2.21        28  201712                          04     0408010
# 21              3.40        56  201712                          04     0408010
# 22              1.51        56  201712                          02     0204000
# 23              7.90       224  201712                          02     0204000
# 24              3.02        35  201712                          03     0304010
# 25              4.86       126  201712                          04     0401010
# 26             18.65       448  201712                          04     0401010
# 27              6.07       140  201712                          04     0401010
# 28             21.76        84  201712                          04     0401020
# 29              6.62       254  201712                          04     0401020
# ...              ...       ...     ...                 ...     ...         ...
# 9818178         7.21         2  201712                          21     2101023
# 9818179        25.36         4  201712                          21     2101023
# 9818180        31.86         7  201712                          21     2101023
# 9818181       113.70        15  201712                          21     2101023
# 9818182         3.51         3  201712                          21     2101250
# 9818183         6.57         1  201712                          21     2112000
# 9818184         5.86       550  201712                          21     2122000
# 9818185         1.86         2  201712                          21     2124000
# 9818186         1.86         2  201712                          21     2124000
# 9818187        15.76         2  201712                          21     2130000
# 9818188         9.22         1  201712                          23     2380209
# 9818189         2.74        56  201712                          02     0201010
# 9818190         3.03        56  201712                          02     0203020
# 9818191         9.38       140  201712                          02     0203020
# 9818192         0.60        10  201712                          04     0401010
# 9818193         2.14        56  201712                          04     0403030
# 9818194        16.41       126  201712                          07     0703010
# 9818195         2.12        56  201712                          10     1001010
# 9818196         1.29        56  201712                          10     1001040
# 9818197         1.11       100  201712                          04     0407010
# 9818198         3.46        60  201712                          05     0502030
# 9818199         5.56       500  201712                          13     1302010
# 9818200        11.14       300  201712                          13     1302010
# 9818201        16.00      1500  201712                          13     1302011
# 9818202         0.91        20  201712                          13     1310020
# 9818203         1.70        30  201712                          13     1310020
# 9818204         2.24       125  201712                          21     2122000
# 9818205         2.95       250  201712                          21     2122000
# 9818206         4.16       500  201712                          21     2122000
# 9818207         5.56         1  201712                          21     2122000
#
# [8071884 rows x 13 columns]

# %%
PracticeBySubChapterSum = PracticeBySubChapter.sum()

# %%
# PracticeBySubChapterSum output
PracticeBySubChapterSum.to_csv('PracticeBySubChapterSum.csv', sep=',')

# %%
presDec17.columns
# Out:
# Index([' SHA', 'PCT', 'PRACTICE', 'BNF CODE',
#        'BNF NAME                                    ', 'ITEMS  ',
#        'NIC        ', 'ACT COST   ', 'QUANTITY', 'PERIOD', '                 ',
#        'CHAPTER', 'SUB_CHAPTER'],
#       dtype='object')

# %%
PracticeBySubChapByCode = presDec17.groupby(['PRACTICE', 'SUB_CHAPTER', 'SUB_CHAPTER_REM'])

# %%
PracticeBySubChapByCode.sum().to_csv('PracticeBySubChapterByBNF.csv', sep=',')

# %%
PracticeBySubChapByCode.describe()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-1761453e97f3> in <module>()
# ----> 1 PracticeBySubChapByCode.describe()
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby.py in describe(self, **kwargs)
#    1309     def describe(self, **kwargs):
#    1310         self._set_group_selection()
# -> 1311         result = self.apply(lambda x: x.describe(**kwargs))
#    1312         if self.axis == 1:
#    1313             return result.T
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby.py in apply(self, func, *args, **kwargs)
#     803         # ignore SettingWithCopy here in case the user mutates
#     804         with option_context('mode.chained_assignment', None):
# --> 805             return self._python_apply_general(f)
#     806
#     807     def _python_apply_general(self, f):
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby.py in _python_apply_general(self, f)
#     807     def _python_apply_general(self, f):
#     808         keys, values, mutated = self.grouper.apply(f, self._selected_obj,
# --> 809                                                    self.axis)
#     810
#     811         return self._wrap_applied_output(
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby.py in apply(self, f, data, axis)
#    1951                 hasattr(splitter, 'fast_apply') and axis == 0):
#    1952             try:
# -> 1953                 values, mutated = splitter.fast_apply(f, group_keys)
#    1954                 return group_keys, values, mutated
#    1955             except (lib.InvalidApply):
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby.py in fast_apply(self, f, names)
#    4710
#    4711         sdata = self._get_sorted_data()
# -> 4712         results, mutated = lib.apply_frame_axis0(sdata, f, names, starts, ends)
#    4713
#    4714         return results, mutated
#
# pandas/_libs/src/reduce.pyx in pandas._libs.lib.apply_frame_axis0()
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby.py in <lambda>(x)
#    1309     def describe(self, **kwargs):
#    1310         self._set_group_selection()
# -> 1311         result = self.apply(lambda x: x.describe(**kwargs))
#    1312         if self.axis == 1:
#    1313             return result.T
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in describe(self, percentiles, include, exclude)
#    6825             data = self.select_dtypes(include=include, exclude=exclude)
#    6826
# -> 6827         ldesc = [describe_1d(s) for _, s in data.iteritems()]
#    6828         # set a convenient order for rows
#    6829         names = []
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in <listcomp>(.0)
#    6825             data = self.select_dtypes(include=include, exclude=exclude)
#    6826
# -> 6827         ldesc = [describe_1d(s) for _, s in data.iteritems()]
#    6828         # set a convenient order for rows
#    6829         names = []
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in describe_1d(data)
#    6804                 return describe_categorical_1d(data)
#    6805             elif is_numeric_dtype(data):
# -> 6806                 return describe_numeric_1d(data)
#    6807             elif is_timedelta64_dtype(data):
#    6808                 return describe_numeric_1d(data)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in describe_numeric_1d(series)
#    6777                           formatted_percentiles + ['max'])
#    6778             d = ([series.count(), series.mean(), series.std(), series.min()] +
# -> 6779                  [series.quantile(x) for x in percentiles] + [series.max()])
#    6780             return pd.Series(d, index=stat_index, name=series.name)
#    6781
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in <listcomp>(.0)
#    6777                           formatted_percentiles + ['max'])
#    6778             d = ([series.count(), series.mean(), series.std(), series.min()] +
# -> 6779                  [series.quantile(x) for x in percentiles] + [series.max()])
#    6780             return pd.Series(d, index=stat_index, name=series.name)
#    6781
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in quantile(self, q, interpolation)
#    1455         self._check_percentile(q)
#    1456
# -> 1457         result = self._data.quantile(qs=q, interpolation=interpolation)
#    1458
#    1459         if is_list_like(q):
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in quantile(self, **kwargs)
#    3436
#    3437     def quantile(self, **kwargs):
# -> 3438         return self.reduction('quantile', **kwargs)
#    3439
#    3440     def setitem(self, **kwargs):
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in reduction(self, f, axis, consolidate, transposed, **kwargs)
#    3365         for b in self.blocks:
#    3366             kwargs['mgr'] = self
# -> 3367             axe, block = getattr(b, f)(axis=axis, **kwargs)
#    3368
#    3369             axes.append(axe)
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in quantile(self, qs, interpolation, axis, mgr)
#    1644                     result = np.array([self._na_value] * len(self))
#    1645             else:
# -> 1646                 result = _nanpercentile(values, qs * 100, axis=axis, **kw)
#    1647
#    1648         ndim = getattr(result, 'ndim', None) or 0
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in _nanpercentile(values, q, axis, **kw)
#    1600                     return result
#    1601             else:
# -> 1602                 return np.percentile(values, q, axis=axis, **kw)
#    1603
#    1604         from pandas import Float64Index
#
# ~\Anaconda3\lib\site-packages\numpy\lib\function_base.py in percentile(a, q, axis, out, overwrite_input, interpolation, keepdims)
#    4272     r, k = _ureduce(a, func=_percentile, q=q, axis=axis, out=out,
#    4273                     overwrite_input=overwrite_input,
# -> 4274                     interpolation=interpolation)
#    4275     if keepdims:
#    4276         if q.ndim == 0:
#
# ~\Anaconda3\lib\site-packages\numpy\lib\function_base.py in _ureduce(a, func, **kwargs)
#    4014         keepdim = [1] * a.ndim
#    4015
# -> 4016     r = func(a, **kwargs)
#    4017     return r, keepdim
#    4018
#
# ~\Anaconda3\lib\site-packages\numpy\lib\function_base.py in _percentile(a, q, axis, out, overwrite_input, interpolation, keepdims)
#    4376         weights_above.shape = weights_shape
#    4377
# -> 4378         ap.partition(concatenate((indices_below, indices_above)), axis=axis)
#    4379
#    4380         # ensure axis with qth is first
#
# KeyboardInterrupt:

# %%
PracticeBySubChapByCode.head()

# %%
BNFCodeNameMap = presDec17[['BNF CODE', 'BNF NAME                                    ', 'SUB_CHAPTER', 'SUB_CHAPTER_REM', 'ITEMS  ',
       'NIC        ', 'ACT COST   ', 'QUANTITY']]

# %%
BNFCodeNameMapUnique = BNFCodeNameMap.drop_duplicates(['BNF CODE'])

# %%
BNFCodeNameMap.head
# Out:
# <bound method NDFrame.head of                 BNF CODE BNF NAME                                      \
# 0        0401010Z0AAAAAA     Zopiclone_Tab 7.5mg
# 1        0401010Z0AAACAC     Zopiclone_Tab 3.75mg
# 2        0401020K0AAAHAH     Diazepam_Tab 2mg
# 3        0401020P0AAABAB     Lorazepam_Tab 1mg
# 4        0402010ABAAABAB     Quetiapine_Tab 25mg
# 5        0402010ABAAAVAV     Quetiapine_Tab 50mg M/R
# 6        0402010ABAAAWAW     Quetiapine_Tab 200mg M/R
# 7        0402010ABAAAXAX     Quetiapine_Tab 300mg M/R
# 8        0402010D0AAAIAI     Chlorpromazine HCl_Tab 25mg
# 9        040201060AAACAC     Olanzapine_Tab 10mg
# 10       040201060AAALAL     Olanzapine_Tab 15mg
# 11       0402030K0BFABAI     Priadel_Tab 200mg
# 12       0403010R0AAAAAA     Lofepramine HCl_Tab 70mg
# 13       0403030D0AAAAAA     Citalopram Hydrob_Tab 20mg
# 14       0403030Q0AAAAAA     Sertraline HCl_Tab 50mg
# 15       0403030Q0AAABAB     Sertraline HCl_Tab 100mg
# 16       0403030X0AAACAC     Escitalopram_Tab 5mg
# 17       0403040X0AAAAAA     Mirtazapine_Tab 30mg
# 18       0403040X0AAANAN     Mirtazapine_Tab 15mg
# 19       0403040Y0AAABAB     Duloxetine HCl_Cap G/R 60mg
# 20       0408010AEAAACAC     Pregabalin_Cap 75mg
# 21       0408010AEAAAEAE     Pregabalin_Cap 150mg
# 22       0204000R0AAAHAH     Propranolol HCl_Tab 10mg
# 23       0204000R0AAAJAJ     Propranolol HCl_Tab 40mg
# 24       0304010W0AAALAL     Promethazine HCl_Tab 25mg
# 25       0401010R0AAACAC     Nitrazepam_Tab 5mg
# 26       0401010Z0AAAAAA     Zopiclone_Tab 7.5mg
# 27       0401010Z0AAACAC     Zopiclone_Tab 3.75mg
# 28       0401020B0AAAAAA     Buspirone HCl_Tab 5mg
# 29       0401020K0AAAHAH     Diazepam_Tab 2mg
# ...                  ...                                          ...
# 9818178  21010230102         Volumatic
# 9818179  21010230111         Volumatic Paed + Mask
# 9818180  21010230115         Aerochamber Plus
# 9818181  21010230116         Aerochamber Plus + Adult/Child/Infant Ma
# 9818182  21012500100         T & R Sod Bicarb Ear Dps 5% Ear Wax Soft
# 9818183  21120000130         Clement Clarke Stnd Range Peak Flow Mete
# 9818184  21220000214         Zerobase Crm (Appl)
# 9818185  21240000105         Mandanol Sod Chlor 0.9% Nsl Dps
# 9818186  21240000120         Almus Sod Chlor 0.9% Nsl Dps
# 9818187  21300000104         Hylo-Tear Sod Hyaluronate Eye Dps 0.1% P
# 9818188  23802098001         H & R_Proshield Plus Skin Prote 115g
# 9818189  0201010F0AAAEAE     Digoxin_Tab 125mcg
# 9818190  0203020D0AAAAAA     Amiodarone HCl_Tab 100mg
# 9818191  0203020D0AAABAB     Amiodarone HCl_Tab 200mg
# 9818192  0401010T0AAAMAM     Temazepam_Tab 10mg
# 9818193  0403030X0AAAAAA     Escitalopram_Tab 10mg
# 9818194  0703010E0AAACAC     Ethinylestr/Gestodene_Tab 20mcg/75mcg
# 9818195  1001010P0AAAEAE     Naproxen_Tab 500mg
# 9818196  1001040C0AAAAAA     Allopurinol_Tab 100mg
# 9818197  0407010H0AAAWAW     Paracet_Oral Susp Paed 120mg/5ml S/F
# 9818198  0502030B0AAABAB     Nystatin_Oral Susp 100 000u/ml
# 9818199  130201000BBAEA3     Diprobase_Oint
# 9818200  130201000BBDPBX     Neutrogena_Norwegian For Dermat Crm
# 9818201  1302011L0BFAAAE     Cetraben_Bath Oil
# 9818202  1310020H0AAABAB     Clotrimazole_Crm 1%
# 9818203  1310020N0AAAAAA     Miconazole Nit_Crm 2%
# 9818204  21220000204         Zeroderm Oint
# 9818205  21220000211         QV Gentle Wsh
# 9818206  21220000217         Zeroneum Bath Add
# 9818207  21220000235         Cetraben Crm 500g
#
#         SUB_CHAPTER SUB_CHAPTER_REM  ITEMS    NIC          ACT COST     \
# 0           0401010        Z0AAAAAA        1         0.47         0.55
# 1           0401010        Z0AAACAC        1         0.46         0.54
# 2           0401020        K0AAAHAH        4         1.62         1.96
# 3           0401020        P0AAABAB        2         0.71         0.88
# 4           0402010        ABAAABAB        1         8.44         7.93
# 5           0402010        ABAAAVAV        1        15.79        14.74
# 6           0402010        ABAAAWAW        1        26.39        24.56
# 7           0402010        ABAAAXAX        1       158.67       147.09
# 8           0402010        D0AAAIAI        3        71.49        66.46
# 9           0402010        60AAACAC        2        33.99        31.61
# 10          0402010        60AAALAL        1         7.58         7.13
# 11          0402030        K0BFABAI        1         0.77         0.83
# 12          0403010        R0AAAAAA        1         2.36         2.30
# 13          0403030        D0AAAAAA        1         0.07         0.18
# 14          0403030        Q0AAAAAA        4         2.01         2.22
# 15          0403030        Q0AAABAB        3         1.86         2.05
# 16          0403030        X0AAACAC        1         0.68         0.74
# 17          0403040        X0AAAAAA        2         1.83         1.82
# 18          0403040        X0AAANAN        6        11.36        11.09
# 19          0403040        Y0AAABAB        1        29.14        27.00
# 20          0408010        AEAAACAC        1         2.26         2.21
# 21          0408010        AEAAAEAE        1         3.66         3.40
# 22          0204000        R0AAAHAH        1         1.62         1.51
# 23          0204000        R0AAAJAJ       14         7.04         7.90
# 24          0304010        W0AAALAL        3         2.90         3.02
# 25          0401010        R0AAACAC       11         4.01         4.86
# 26          0401010        Z0AAAAAA       42        15.16        18.65
# 27          0401010        Z0AAACAC       16         4.60         6.07
# 28          0401020        B0AAAAAA        2        23.24        21.76
# 29          0401020        K0AAAHAH       12         6.01         6.62
# ...             ...             ...      ...          ...          ...
# 9818178     2101023        0102            2         7.76         7.21
# 9818179     2101023        0111            4        27.32        25.36
# 9818180     2101023        0115            7        34.30        31.86
# 9818181     2101023        0116           15       122.55       113.70
# 9818182     2101250        0100            3         3.75         3.51
# 9818183     2112000        0130            1         7.08         6.57
# 9818184     2122000        0214            2         6.30         5.86
# 9818185     2124000        0105            2         1.98         1.86
# 9818186     2124000        0120            2         1.98         1.86
# 9818187     2130000        0104            1        17.00        15.76
# 9818188     2380209        8001            1         9.94         9.22
# 9818189     0201010        F0AAAEAE        1         2.94         2.74
# 9818190     0203020        D0AAAAAA        1         3.26         3.03
# 9818191     0203020        D0AAABAB        2        10.10         9.38
# 9818192     0401010        T0AAAMAM        1         0.53         0.60
# 9818193     0403030        X0AAAAAA        1         2.30         2.14
# 9818194     0703010        E0AAACAC        1        17.70        16.41
# 9818195     1001010        P0AAAEAE        1         2.28         2.12
# 9818196     1001040        C0AAAAAA        1         1.38         1.29
# 9818197     0407010        H0AAAWAW        1         1.19         1.11
# 9818198     0502030        B0AAABAB        1         3.72         3.46
# 9818199     1302010        00BBAEA3        1         5.99         5.56
# 9818200     1302010        00BBDPBX        2        12.00        11.14
# 9818201     1302011        L0BFAAAE        2        17.25        16.00
# 9818202     1310020        H0AAABAB        1         0.97         0.91
# 9818203     1310020        N0AAAAAA        1         1.82         1.70
# 9818204     2122000        0204            1         2.41         2.24
# 9818205     2122000        0211            1         3.17         2.95
# 9818206     2122000        0217            1         4.48         4.16
# 9818207     2122000        0235            1         5.99         5.56
#
#          QUANTITY
# 0              14
# 1              14
# 2              69
# 3               5
# 4              42
# 5              14
# 6              14
# 7              56
# 8              63
# 9              35
# 10              7
# 11             28
# 12             14
# 13              1
# 14             63
# 15             49
# 16             21
# 17             42
# 18            112
# 19             56
# 20             28
# 21             56
# 22             56
# 23            224
# 24             35
# 25            126
# 26            448
# 27            140
# 28             84
# 29            254
# ...           ...
# 9818178         2
# 9818179         4
# 9818180         7
# 9818181        15
# 9818182         3
# 9818183         1
# 9818184       550
# 9818185         2
# 9818186         2
# 9818187         2
# 9818188         1
# 9818189        56
# 9818190        56
# 9818191       140
# 9818192        10
# 9818193        56
# 9818194       126
# 9818195        56
# 9818196        56
# 9818197       100
# 9818198        60
# 9818199       500
# 9818200       300
# 9818201      1500
# 9818202        20
# 9818203        30
# 9818204       125
# 9818205       250
# 9818206       500
# 9818207         1
#
# [9818208 rows x 8 columns]>

# %%
BNFCodeNameMapUnique.head
# Out:
# <bound method NDFrame.head of                 BNF CODE BNF NAME                                      \
# 0        0401010Z0AAAAAA     Zopiclone_Tab 7.5mg
# 1        0401010Z0AAACAC     Zopiclone_Tab 3.75mg
# 2        0401020K0AAAHAH     Diazepam_Tab 2mg
# 3        0401020P0AAABAB     Lorazepam_Tab 1mg
# 4        0402010ABAAABAB     Quetiapine_Tab 25mg
# 5        0402010ABAAAVAV     Quetiapine_Tab 50mg M/R
# 6        0402010ABAAAWAW     Quetiapine_Tab 200mg M/R
# 7        0402010ABAAAXAX     Quetiapine_Tab 300mg M/R
# 8        0402010D0AAAIAI     Chlorpromazine HCl_Tab 25mg
# 9        040201060AAACAC     Olanzapine_Tab 10mg
# 10       040201060AAALAL     Olanzapine_Tab 15mg
# 11       0402030K0BFABAI     Priadel_Tab 200mg
# 12       0403010R0AAAAAA     Lofepramine HCl_Tab 70mg
# 13       0403030D0AAAAAA     Citalopram Hydrob_Tab 20mg
# 14       0403030Q0AAAAAA     Sertraline HCl_Tab 50mg
# 15       0403030Q0AAABAB     Sertraline HCl_Tab 100mg
# 16       0403030X0AAACAC     Escitalopram_Tab 5mg
# 17       0403040X0AAAAAA     Mirtazapine_Tab 30mg
# 18       0403040X0AAANAN     Mirtazapine_Tab 15mg
# 19       0403040Y0AAABAB     Duloxetine HCl_Cap G/R 60mg
# 20       0408010AEAAACAC     Pregabalin_Cap 75mg
# 21       0408010AEAAAEAE     Pregabalin_Cap 150mg
# 22       0204000R0AAAHAH     Propranolol HCl_Tab 10mg
# 23       0204000R0AAAJAJ     Propranolol HCl_Tab 40mg
# 24       0304010W0AAALAL     Promethazine HCl_Tab 25mg
# 25       0401010R0AAACAC     Nitrazepam_Tab 5mg
# 28       0401020B0AAAAAA     Buspirone HCl_Tab 5mg
# 30       0401020K0AAAIAI     Diazepam_Tab 5mg
# 33       0402010ABAAACAC     Quetiapine_Tab 100mg
# 34       0402010ABAAAFAF     Quetiapine_Tab 150mg
# ...                  ...                                          ...
# 9737193  23353453783         Pelican_Platinum Convex Clsd Pch Clr Stn
# 9738835  23303373055         Respond_OstoMart Cool Comfort Unisex Gmt
# 9740610  0408010AEBDAFAF     Lecaent_Cap 200mg
# 9741398  20100000547         Mediplast 2.5cm x 5m Surg Adh Tape Perm
# 9744935  21011200218         Milex Gellhorn Pess Slc Short Stem 83mm
# 9744936  21011200219         Milex Gellhorn Pess Slc Short Stem 89mm
# 9746839  0503010ACAAAGAG     Darunavir_Tab 800mg
# 9746840  0503010U0AAACAC     Ritonavir_Tab 100mg
# 9746841  0503010Z0BBAAAA     Kivexa_Tab
# 9758364  0207030A0AAADAD     Adren_Inj 1/10 000 1ml Amp
# 9759677  23353453774         Pelican_Platinum Contour Convex Clsd Pch
# 9760853  21270000909         Jobst Elvarex Soft for L/Extrem Class 3
# 9765052  0802040ADAAAAAA     Fingolimod HCl_Cap 500mcg
# 9768927  23603456141         Pelican_Select Afresh Drnbl Pouch Clr St
# 9769174  0206010K0BCABAH     Modisal LA 25_Cap 25mg
# 9773141  21270000858         Sigvaris Comfort Class 2 Panty Extra C/T
# 9777938  21240000125         Aqua Maris Daily Nsl Spy
# 9778847  0703010P0AAAAAA     Gppe Tab_Logynon
# 9779283  20031200033         Geliperm 10cm x 10cm Wound Dress H/Gel S
# 9783399  23301023198         Kavendor_Comfizz Stoma Support Wear Unis
# 9788698  0411000F0BCACAG     Galsya XL_Cap 24mg
# 9790400  21270001448         Juzo Expert Strong Class 2 Glove+Open Fi
# 9790401  21270001457         Juzo Expert Strong Acc For U/Limb Border
# 9790402  21270001461         Juzo Expert Strong Acc For U/Limb Overhe
# 9796723  21011200413         GBUK Gellhorn Pess Slc Stnd Stem Size 4
# 9796724  21011200423         GBUK Gellhorn Pess Slc Short Stem Size 5
# 9796940  23940709792         Dansac_NovaLife 2 Flng 36mm C/Fit 25-28m
# 9803426  1202020L0AACDCD     Sod Chlor_Neb Soln 7% 5ml Btl
# 9803737  21270001801         Juzo Dynamic Cott Custom Fit L/Limb Clas
# 9813811  23940459683         B.Braun_Softima 3S Closed Pouch Midi Bei
#
#         SUB_CHAPTER SUB_CHAPTER_REM  ITEMS    NIC          ACT COST     \
# 0           0401010        Z0AAAAAA        1         0.47         0.55
# 1           0401010        Z0AAACAC        1         0.46         0.54
# 2           0401020        K0AAAHAH        4         1.62         1.96
# 3           0401020        P0AAABAB        2         0.71         0.88
# 4           0402010        ABAAABAB        1         8.44         7.93
# 5           0402010        ABAAAVAV        1        15.79        14.74
# 6           0402010        ABAAAWAW        1        26.39        24.56
# 7           0402010        ABAAAXAX        1       158.67       147.09
# 8           0402010        D0AAAIAI        3        71.49        66.46
# 9           0402010        60AAACAC        2        33.99        31.61
# 10          0402010        60AAALAL        1         7.58         7.13
# 11          0402030        K0BFABAI        1         0.77         0.83
# 12          0403010        R0AAAAAA        1         2.36         2.30
# 13          0403030        D0AAAAAA        1         0.07         0.18
# 14          0403030        Q0AAAAAA        4         2.01         2.22
# 15          0403030        Q0AAABAB        3         1.86         2.05
# 16          0403030        X0AAACAC        1         0.68         0.74
# 17          0403040        X0AAAAAA        2         1.83         1.82
# 18          0403040        X0AAANAN        6        11.36        11.09
# 19          0403040        Y0AAABAB        1        29.14        27.00
# 20          0408010        AEAAACAC        1         2.26         2.21
# 21          0408010        AEAAAEAE        1         3.66         3.40
# 22          0204000        R0AAAHAH        1         1.62         1.51
# 23          0204000        R0AAAJAJ       14         7.04         7.90
# 24          0304010        W0AAALAL        3         2.90         3.02
# 25          0401010        R0AAACAC       11         4.01         4.86
# 28          0401020        B0AAAAAA        2        23.24        21.76
# 30          0401020        K0AAAIAI       27        11.41        12.80
# 33          0402010        ABAAACAC       11        85.05        80.01
# 34          0402010        ABAAAFAF        4        41.58        38.97
# ...             ...             ...      ...          ...          ...
# 9737193     2335345        3783            1       222.81       206.38
# 9738835     2330337        3055            1        68.52        63.47
# 9740610     0408010        AEBDAFAF        1        96.59        89.47
# 9741398     2010000        0547            1         0.50         0.48
# 9744935     2101120        0218            1        22.92        21.24
# 9744936     2101120        0219            1        22.92        21.24
# 9746839     0503010        ACAAAGAG        1       297.80       275.86
# 9746840     0503010        U0AAACAC        1        19.44        18.02
# 9746841     0503010        Z0BBAAAA        1       299.41       277.35
# 9758364     0207030        A0AAADAD        1         6.94         6.43
# 9759677     2335345        3774            1        63.66        58.97
# 9760853     2127000        0909            1       158.26       146.61
# 9765052     0802040        ADAAAAAA        1        52.50        48.74
# 9768927     2360345        6141            1        86.36        79.99
# 9769174     0206010        K0BCABAH        1        26.36        24.43
# 9773141     2127000        0858            1        52.55        48.69
# 9777938     2124000        0125            1         2.49         2.32
# 9778847     0703010        P0AAAAAA        1         3.82         3.58
# 9779283     2003120        0033            1         2.53         2.36
# 9783399     2330102        3198            1        51.60        47.80
# 9788698     0411000        F0BCACAG        1        67.83        62.84
# 9790400     2127000        1448            1       121.22       112.28
# 9790401     2127000        1457            1         8.06         7.47
# 9790402     2127000        1461            1        12.22        11.32
# 9796723     2101120        0413            1        20.49        18.99
# 9796724     2101120        0423            2        40.98        37.98
# 9796940     2394070        9792            1       142.03       131.56
# 9803426     1202020        L0AACDCD        1      3072.33      2845.85
# 9803737     2127000        1801            1       108.00       100.05
# 9813811     2394045        9683            2        94.68        87.70
#
#          QUANTITY
# 0              14
# 1              14
# 2              69
# 3               5
# 4              42
# 5              14
# 6              14
# 7              56
# 8              63
# 9              35
# 10              7
# 11             28
# 12             14
# 13              1
# 14             63
# 15             49
# 16             21
# 17             42
# 18            112
# 19             56
# 20             28
# 21             56
# 22             56
# 23            224
# 24             35
# 25            126
# 28             84
# 30            461
# 33            147
# 34             49
# ...           ...
# 9737193        70
# 9738835         6
# 9740610        84
# 9741398         1
# 9744935         1
# 9744936         1
# 9746839        30
# 9746840        30
# 9746841        30
# 9758364         1
# 9759677        20
# 9760853         2
# 9765052         1
# 9768927        30
# 9769174        56
# 9773141         1
# 9777938        30
# 9778847        63
# 9779283         1
# 9783399         3
# 9788698        28
# 9790400         2
# 9790401         2
# 9790402         2
# 9796723         1
# 9796724         2
# 9796940        35
# 9803426        20
# 9803737         4
# 9813811        60
#
# [22186 rows x 8 columns]>

# %%
BNFCodeNameMapUnique.to_csv('BNF_CodeNameCostMap.csv', sep=',')

# %%
BNFCodeNameMap.to_csv('BNF_CodeNameCostMapDupli.csv', sep=',')
