# %% [markdown]
# # This notebook analyses the files generated by subchapter by each cluster
# ## Specific interest is on medicines/drugs categories listed below :
# ## * 0601021* Oral hypoglycaemics
# ## * 0601022* Metformin
# ## * 0601023* Gliptins
# ## * 0601011* Insulin
# ## * 0601012*Insulin
# ## * 0704050* Viagra and others
#
# ## The files generated from PrescriptionData-ChapterBased-Cluster-Correlation jupyter notebook are used for further analysis.

# %%
import pandas as pd
from IPython.display import Image
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import Markdown, display # to print markdown text

# %%
# Print bold text
def print_markdown(string): display(Markdown(string))

# %%
SubChapterCategories = ['0601021', '0601022', '0601023', '0601011', '0601012', '0704050']

# %% [markdown]
# ## Based on the cluster analysis, the 3D visualization of the clusters based on Average Age Profile of a GP, % of Diabetic Patients and Index of Multiple Deprivation

# %%
Image("insights/3DClusterDiabetics_PlotLy.png")

# %%
# Generated files
Cluster0 = ['DARK_BLUE', 'PracticeBySubChapterByCluster_0.csv']
Cluster1 = ['BLUE', 'PracticeBySubChapterByCluster_1.csv']
Cluster2 = ['ORANGE', 'PracticeBySubChapterByCluster_2.csv']
Cluster3 = ['RED', 'PracticeBySubChapterByCluster_3.csv']

# %%
Cluster_CsvData = [Cluster0, Cluster1, Cluster2, Cluster3]

# %%
# Drug groups
Oral_Hypog = ['Oral hypoglycaemics', 601021]
Metformin = ['Metformin', 601022]
Gliptins = ['Gliptins', 601023]
Insulin1 = ['Insulin1', 601011]
Insulin2 = ['Insulin', 601012]
Viagra_others = ['Viagra and others', 704050]

# %%
DrugGroups = [Oral_Hypog, Metformin, Gliptins, Insulin1, Insulin2, Viagra_others]

# %%
# Generate scatter plots for each cluster based on each drug group
ClusterIndex = 0
for cluster in Cluster_CsvData:
    Cluster_Data = pd.read_csv(cluster[1], sep=',', encoding = "ISO-8859-1")
    Cluster_Data['AVERAGE_NIC'] = Cluster_Data['NIC        ']/Cluster_Data['ITEMS  '] 
    for DrugGroup in DrugGroups:
        print_markdown('## Cluster ' + str(ClusterIndex) + ' ' + cluster[0] + ' ' + DrugGroup[0])
        Filter = Cluster_Data['SUB_CHAPTER'] == DrugGroup[1]
        Cluster_Filter = Data = Cluster_Data[Filter]

        sns.set(color_codes=True)
        sns.distplot(Cluster_Filter['NIC        ']);
        plt.show()

        x = Cluster_Filter['ITEMS  ']
        y = Cluster_Filter['NIC        ']

        plt.scatter(x, y)
        plt.xlabel("Number of Items")
        plt.ylabel("Total NIC")
        plt.show()
        print(Cluster_Filter['AVERAGE_NIC'].describe())
    ClusterIndex += 1
# Out:
# ## Cluster 0 DARK_BLUE Oral hypoglycaemics
# count    1017.000000
# mean        3.524363
# std         1.640807
# min         0.727857
# 25%         2.438716
# 50%         3.244032
# 75%         4.223514
# max        13.440000
# Name: AVERAGE_NIC, dtype: float64
# ## Cluster 0 DARK_BLUE Metformin
# count    1019.000000
# mean        4.382177
# std         1.501384
# min         1.387813
# 25%         3.281617
# 50%         4.072058
# 75%         5.187526
# max        10.887778
# Name: AVERAGE_NIC, dtype: float64
# ## Cluster 0 DARK_BLUE Gliptins
# count    1015.000000
# mean       41.481044
# std        13.977183
# min        10.400000
# 25%        31.912993
# 50%        39.595696
# 75%        49.398186
# max       103.825000
# Name: AVERAGE_NIC, dtype: float64
# ## Cluster 0 DARK_BLUE Insulin1
# count    1014.000000
# mean       47.189753
# std        11.678948
# min         5.890000
# 25%        40.073769
# 50%        45.618875
# 75%        52.188852
# max       128.907500
# Name: AVERAGE_NIC, dtype: float64
# ## Cluster 0 DARK_BLUE Insulin
# count    1018.000000
# mean       50.539152
# std        10.271582
# min         8.300000
# 25%        43.796545
# 50%        49.390357
# 75%        55.911705
# max       107.885000
# Name: AVERAGE_NIC, dtype: float64
# ## Cluster 0 DARK_BLUE Viagra and others
# count    1019.000000
# mean       14.086969
# std        10.270901
# min         0.445000
# 25%         7.417754
# 50%        12.034348
# 75%        18.458258
# max        97.200000
# Name: AVERAGE_NIC, dtype: float64
# ## Cluster 1 BLUE Oral hypoglycaemics
# count    2417.000000
# mean        3.672414
# std         1.379659
# min         0.760000
# 25%         2.682667
# 50%         3.413775
# 75%         4.361111
# max        17.670000
# Name: AVERAGE_NIC, dtype: float64
# ## Cluster 1 BLUE Metformin
# count    2419.000000
# mean        4.661208
# std         1.429235
# min         0.750000
# 25%         3.555763
# 50%         4.449839
# 75%         5.492566
# max        14.731250
# Name: AVERAGE_NIC, dtype: float64
# ## Cluster 1 BLUE Gliptins
# count    2415.000000
# mean       43.401047
# std        12.893334
# min         0.800000
# 25%        34.030587
# 50%        41.124474
# 75%        51.452941
# max       139.456667
# Name: AVERAGE_NIC, dtype: float64
# ## Cluster 1 BLUE Insulin1
# count    2413.000000
# mean       48.378475
# std        11.658558
# min        15.912000
# 25%        42.155000
# 50%        47.148750
# 75%        53.061053
# max       325.328235
# Name: AVERAGE_NIC, dtype: float64
# ## Cluster 1 BLUE Insulin
# count    2416.000000
# mean       51.622675
# std         8.833512
# min        17.120325
# 25%        45.675750
# 50%        50.650686
# 75%        56.329695
# max       124.500000
# Name: AVERAGE_NIC, dtype: float64
# ## Cluster 1 BLUE Viagra and others
# count    2415.000000
# mean       13.047671
# std         7.211594
# min         0.713684
# 25%         8.165381
# 50%        11.841864
# 75%        16.403490
# max        63.421667
# Name: AVERAGE_NIC, dtype: float64
# ## Cluster 2 ORANGE Oral hypoglycaemics
# count    1883.000000
# mean        3.405847
# std         1.289056
# min         1.050000
# 25%         2.516001
# 50%         3.183446
# 75%         3.996373
# max        11.560000
# Name: AVERAGE_NIC, dtype: float64
# ## Cluster 2 ORANGE Metformin
# count    1890.000000
# mean        4.126706
# std         1.250734
# min         0.750000
# 25%         3.218162
# 50%         3.973614
# 75%         4.791729
# max        11.368485
# Name: AVERAGE_NIC, dtype: float64
# ## Cluster 2 ORANGE Gliptins
# count    1885.000000
# mean       38.504625
# std        11.131612
# min         0.800000
# 25%        31.471321
# 50%        37.436667
# 75%        44.318889
# max       100.538056
# Name: AVERAGE_NIC, dtype: float64
# ## Cluster 2 ORANGE Insulin1
# count    1878.000000
# mean       45.570993
# std        11.152777
# min         6.120000
# 25%        38.809600
# 50%        43.808684
# 75%        50.379786
# max       148.052500
# Name: AVERAGE_NIC, dtype: float64
# ## Cluster 2 ORANGE Insulin
# count    1883.000000
# mean       49.633896
# std         9.275972
# min        19.116897
# 25%        43.726813
# 50%        48.765690
# 75%        54.528055
# max       135.980000
# Name: AVERAGE_NIC, dtype: float64
# ## Cluster 2 ORANGE Viagra and others
# count    1882.000000
# mean       11.811450
# std         7.344857
# min         0.688750
# 25%         7.004654
# 50%        10.701667
# 75%        15.166244
# max        97.110000
# Name: AVERAGE_NIC, dtype: float64
# ## Cluster 3 RED Oral hypoglycaemics
# count    1798.000000
# mean        3.358839
# std         1.243718
# min         0.781538
# 25%         2.507304
# 50%         3.120263
# 75%         3.958056
# max        15.699286
# Name: AVERAGE_NIC, dtype: float64
# ## Cluster 3 RED Metformin
# count    1798.000000
# mean        4.339789
# std         1.347811
# min         0.990000
# 25%         3.377748
# 50%         4.076644
# 75%         5.036250
# max        12.148200
# Name: AVERAGE_NIC, dtype: float64
# ## Cluster 3 RED Gliptins
# count    1797.000000
# mean       39.640738
# std        10.886288
# min         8.737174
# 25%        32.486424
# 50%        38.048129
# 75%        45.406210
# max       108.742500
# Name: AVERAGE_NIC, dtype: float64
# ## Cluster 3 RED Insulin1
# count    1795.000000
# mean       46.366118
# std         9.244331
# min         7.709457
# 25%        40.518750
# 50%        45.073600
# 75%        50.562994
# max       148.210000
# Name: AVERAGE_NIC, dtype: float64
# ## Cluster 3 RED Insulin
# count    1796.000000
# mean       49.911871
# std         8.395744
# min         9.759366
# 25%        44.377369
# 50%        48.987192
# 75%        54.095357
# max       112.637500
# Name: AVERAGE_NIC, dtype: float64
# ## Cluster 3 RED Viagra and others
# count    1795.000000
# mean       12.077582
# std         6.380012
# min         0.710000
# 25%         7.729165
# 50%        11.170000
# 75%        15.297639
# max        69.345714
# Name: AVERAGE_NIC, dtype: float64

# %%
# Generate scatter plots for each cluster based on each drug group
ClusterIndex = 0
for cluster in Cluster_CsvData:
    Cluster_Data = pd.read_csv(cluster[1], sep=',', encoding = "ISO-8859-1")
    Cluster_Data['AVERAGE_NIC'] = Cluster_Data['NIC        ']/Cluster_Data['ITEMS  '] 
    for DrugGroup in DrugGroups:
        print_markdown('## Cluster ' + str(ClusterIndex) + ' ' + cluster[0] + ' ' + DrugGroup[0])
        Filter = Cluster_Data['SUB_CHAPTER'] == DrugGroup[1]
        Cluster_Filter = Data = Cluster_Data[Filter]

        sns.set(color_codes=True)
        sns.distplot(Cluster_Filter['NIC        ']);
        plt.show()

        x = Cluster_Filter['NIC        ']
        y = Cluster_Filter['ITEMS  ']

        plt.scatter(x, y)
        plt.xlabel("Total NIC")
        plt.ylabel("Number of Items")
        plt.show()
        print(Cluster_Filter['AVERAGE_NIC'].describe())
    ClusterIndex += 1
# Out:
# ## Cluster 0 DARK_BLUE Oral hypoglycaemics
# count    1017.000000
# mean        3.524363
# std         1.640807
# min         0.727857
# 25%         2.438716
# 50%         3.244032
# 75%         4.223514
# max        13.440000
# Name: AVERAGE_NIC, dtype: float64
# ## Cluster 0 DARK_BLUE Metformin
# count    1019.000000
# mean        4.382177
# std         1.501384
# min         1.387813
# 25%         3.281617
# 50%         4.072058
# 75%         5.187526
# max        10.887778
# Name: AVERAGE_NIC, dtype: float64
# ## Cluster 0 DARK_BLUE Gliptins
# count    1015.000000
# mean       41.481044
# std        13.977183
# min        10.400000
# 25%        31.912993
# 50%        39.595696
# 75%        49.398186
# max       103.825000
# Name: AVERAGE_NIC, dtype: float64
# ## Cluster 0 DARK_BLUE Insulin1
# count    1014.000000
# mean       47.189753
# std        11.678948
# min         5.890000
# 25%        40.073769
# 50%        45.618875
# 75%        52.188852
# max       128.907500
# Name: AVERAGE_NIC, dtype: float64
# ## Cluster 0 DARK_BLUE Insulin
# count    1018.000000
# mean       50.539152
# std        10.271582
# min         8.300000
# 25%        43.796545
# 50%        49.390357
# 75%        55.911705
# max       107.885000
# Name: AVERAGE_NIC, dtype: float64
# ## Cluster 0 DARK_BLUE Viagra and others
# count    1019.000000
# mean       14.086969
# std        10.270901
# min         0.445000
# 25%         7.417754
# 50%        12.034348
# 75%        18.458258
# max        97.200000
# Name: AVERAGE_NIC, dtype: float64
# ## Cluster 1 BLUE Oral hypoglycaemics
# count    2417.000000
# mean        3.672414
# std         1.379659
# min         0.760000
# 25%         2.682667
# 50%         3.413775
# 75%         4.361111
# max        17.670000
# Name: AVERAGE_NIC, dtype: float64
# ## Cluster 1 BLUE Metformin
# count    2419.000000
# mean        4.661208
# std         1.429235
# min         0.750000
# 25%         3.555763
# 50%         4.449839
# 75%         5.492566
# max        14.731250
# Name: AVERAGE_NIC, dtype: float64
# ## Cluster 1 BLUE Gliptins
# count    2415.000000
# mean       43.401047
# std        12.893334
# min         0.800000
# 25%        34.030587
# 50%        41.124474
# 75%        51.452941
# max       139.456667
# Name: AVERAGE_NIC, dtype: float64
# ## Cluster 1 BLUE Insulin1
# count    2413.000000
# mean       48.378475
# std        11.658558
# min        15.912000
# 25%        42.155000
# 50%        47.148750
# 75%        53.061053
# max       325.328235
# Name: AVERAGE_NIC, dtype: float64
# ## Cluster 1 BLUE Insulin
# count    2416.000000
# mean       51.622675
# std         8.833512
# min        17.120325
# 25%        45.675750
# 50%        50.650686
# 75%        56.329695
# max       124.500000
# Name: AVERAGE_NIC, dtype: float64
# ## Cluster 1 BLUE Viagra and others
# count    2415.000000
# mean       13.047671
# std         7.211594
# min         0.713684
# 25%         8.165381
# 50%        11.841864
# 75%        16.403490
# max        63.421667
# Name: AVERAGE_NIC, dtype: float64
# ## Cluster 2 ORANGE Oral hypoglycaemics
# count    1883.000000
# mean        3.405847
# std         1.289056
# min         1.050000
# 25%         2.516001
# 50%         3.183446
# 75%         3.996373
# max        11.560000
# Name: AVERAGE_NIC, dtype: float64
# ## Cluster 2 ORANGE Metformin
# count    1890.000000
# mean        4.126706
# std         1.250734
# min         0.750000
# 25%         3.218162
# 50%         3.973614
# 75%         4.791729
# max        11.368485
# Name: AVERAGE_NIC, dtype: float64
# ## Cluster 2 ORANGE Gliptins
# count    1885.000000
# mean       38.504625
# std        11.131612
# min         0.800000
# 25%        31.471321
# 50%        37.436667
# 75%        44.318889
# max       100.538056
# Name: AVERAGE_NIC, dtype: float64
# ## Cluster 2 ORANGE Insulin1
# count    1878.000000
# mean       45.570993
# std        11.152777
# min         6.120000
# 25%        38.809600
# 50%        43.808684
# 75%        50.379786
# max       148.052500
# Name: AVERAGE_NIC, dtype: float64
# ## Cluster 2 ORANGE Insulin
# count    1883.000000
# mean       49.633896
# std         9.275972
# min        19.116897
# 25%        43.726813
# 50%        48.765690
# 75%        54.528055
# max       135.980000
# Name: AVERAGE_NIC, dtype: float64
# ## Cluster 2 ORANGE Viagra and others
# count    1882.000000
# mean       11.811450
# std         7.344857
# min         0.688750
# 25%         7.004654
# 50%        10.701667
# 75%        15.166244
# max        97.110000
# Name: AVERAGE_NIC, dtype: float64
# ## Cluster 3 RED Oral hypoglycaemics
# count    1798.000000
# mean        3.358839
# std         1.243718
# min         0.781538
# 25%         2.507304
# 50%         3.120263
# 75%         3.958056
# max        15.699286
# Name: AVERAGE_NIC, dtype: float64
# ## Cluster 3 RED Metformin
# count    1798.000000
# mean        4.339789
# std         1.347811
# min         0.990000
# 25%         3.377748
# 50%         4.076644
# 75%         5.036250
# max        12.148200
# Name: AVERAGE_NIC, dtype: float64
# ## Cluster 3 RED Gliptins
# count    1797.000000
# mean       39.640738
# std        10.886288
# min         8.737174
# 25%        32.486424
# 50%        38.048129
# 75%        45.406210
# max       108.742500
# Name: AVERAGE_NIC, dtype: float64
# ## Cluster 3 RED Insulin1
# count    1795.000000
# mean       46.366118
# std         9.244331
# min         7.709457
# 25%        40.518750
# 50%        45.073600
# 75%        50.562994
# max       148.210000
# Name: AVERAGE_NIC, dtype: float64
# ## Cluster 3 RED Insulin
# count    1796.000000
# mean       49.911871
# std         8.395744
# min         9.759366
# 25%        44.377369
# 50%        48.987192
# 75%        54.095357
# max       112.637500
# Name: AVERAGE_NIC, dtype: float64
# ## Cluster 3 RED Viagra and others
# count    1795.000000
# mean       12.077582
# std         6.380012
# min         0.710000
# 25%         7.729165
# 50%        11.170000
# 75%        15.297639
# max        69.345714
# Name: AVERAGE_NIC, dtype: float64

# %%
# Generate scatter plots for each cluster based on each drug group : Average NIC vs ITEMS
ClusterIndex = 0
for cluster in Cluster_CsvData:
    Cluster_Data = pd.read_csv(cluster[1], sep=',', encoding = "ISO-8859-1")
    Cluster_Data['AVERAGE_NIC'] = Cluster_Data['NIC        ']/Cluster_Data['ITEMS  '] 
    for DrugGroup in DrugGroups:
        print_markdown('## Cluster ' + str(ClusterIndex) + ' ' + cluster[0] + ' ' + DrugGroup[0])
        Filter = Cluster_Data['SUB_CHAPTER'] == DrugGroup[1]
        Cluster_Filter = Cluster_Data[Filter]

        sns.set(color_codes=True)
        sns.distplot(Cluster_Filter['AVERAGE_NIC']);
        plt.show()

        x = Cluster_Filter['AVERAGE_NIC']
        y = Cluster_Filter['ITEMS  ']

        plt.scatter(x, y)
        plt.xlabel("Average NIC")
        plt.ylabel("Number of Items")
        plt.show()
        print(Cluster_Filter['AVERAGE_NIC'].describe())
    ClusterIndex += 1
# Out:
# ## Cluster 0 DARK_BLUE Oral hypoglycaemics
# count    1017.000000
# mean        3.524363
# std         1.640807
# min         0.727857
# 25%         2.438716
# 50%         3.244032
# 75%         4.223514
# max        13.440000
# Name: AVERAGE_NIC, dtype: float64
# ## Cluster 0 DARK_BLUE Metformin
# count    1019.000000
# mean        4.382177
# std         1.501384
# min         1.387813
# 25%         3.281617
# 50%         4.072058
# 75%         5.187526
# max        10.887778
# Name: AVERAGE_NIC, dtype: float64
# ## Cluster 0 DARK_BLUE Gliptins
# count    1015.000000
# mean       41.481044
# std        13.977183
# min        10.400000
# 25%        31.912993
# 50%        39.595696
# 75%        49.398186
# max       103.825000
# Name: AVERAGE_NIC, dtype: float64
# ## Cluster 0 DARK_BLUE Insulin1
# count    1014.000000
# mean       47.189753
# std        11.678948
# min         5.890000
# 25%        40.073769
# 50%        45.618875
# 75%        52.188852
# max       128.907500
# Name: AVERAGE_NIC, dtype: float64
# ## Cluster 0 DARK_BLUE Insulin
# count    1018.000000
# mean       50.539152
# std        10.271582
# min         8.300000
# 25%        43.796545
# 50%        49.390357
# 75%        55.911705
# max       107.885000
# Name: AVERAGE_NIC, dtype: float64
# ## Cluster 0 DARK_BLUE Viagra and others
# count    1019.000000
# mean       14.086969
# std        10.270901
# min         0.445000
# 25%         7.417754
# 50%        12.034348
# 75%        18.458258
# max        97.200000
# Name: AVERAGE_NIC, dtype: float64
# ## Cluster 1 BLUE Oral hypoglycaemics
# count    2417.000000
# mean        3.672414
# std         1.379659
# min         0.760000
# 25%         2.682667
# 50%         3.413775
# 75%         4.361111
# max        17.670000
# Name: AVERAGE_NIC, dtype: float64
# ## Cluster 1 BLUE Metformin
# count    2419.000000
# mean        4.661208
# std         1.429235
# min         0.750000
# 25%         3.555763
# 50%         4.449839
# 75%         5.492566
# max        14.731250
# Name: AVERAGE_NIC, dtype: float64
# ## Cluster 1 BLUE Gliptins
# count    2415.000000
# mean       43.401047
# std        12.893334
# min         0.800000
# 25%        34.030587
# 50%        41.124474
# 75%        51.452941
# max       139.456667
# Name: AVERAGE_NIC, dtype: float64
# ## Cluster 1 BLUE Insulin1
# count    2413.000000
# mean       48.378475
# std        11.658558
# min        15.912000
# 25%        42.155000
# 50%        47.148750
# 75%        53.061053
# max       325.328235
# Name: AVERAGE_NIC, dtype: float64
# ## Cluster 1 BLUE Insulin
# count    2416.000000
# mean       51.622675
# std         8.833512
# min        17.120325
# 25%        45.675750
# 50%        50.650686
# 75%        56.329695
# max       124.500000
# Name: AVERAGE_NIC, dtype: float64
# ## Cluster 1 BLUE Viagra and others
# count    2415.000000
# mean       13.047671
# std         7.211594
# min         0.713684
# 25%         8.165381
# 50%        11.841864
# 75%        16.403490
# max        63.421667
# Name: AVERAGE_NIC, dtype: float64
# ## Cluster 2 ORANGE Oral hypoglycaemics
# count    1883.000000
# mean        3.405847
# std         1.289056
# min         1.050000
# 25%         2.516001
# 50%         3.183446
# 75%         3.996373
# max        11.560000
# Name: AVERAGE_NIC, dtype: float64
# ## Cluster 2 ORANGE Metformin
# count    1890.000000
# mean        4.126706
# std         1.250734
# min         0.750000
# 25%         3.218162
# 50%         3.973614
# 75%         4.791729
# max        11.368485
# Name: AVERAGE_NIC, dtype: float64
# ## Cluster 2 ORANGE Gliptins
# count    1885.000000
# mean       38.504625
# std        11.131612
# min         0.800000
# 25%        31.471321
# 50%        37.436667
# 75%        44.318889
# max       100.538056
# Name: AVERAGE_NIC, dtype: float64
# ## Cluster 2 ORANGE Insulin1
# count    1878.000000
# mean       45.570993
# std        11.152777
# min         6.120000
# 25%        38.809600
# 50%        43.808684
# 75%        50.379786
# max       148.052500
# Name: AVERAGE_NIC, dtype: float64
# ## Cluster 2 ORANGE Insulin
# count    1883.000000
# mean       49.633896
# std         9.275972
# min        19.116897
# 25%        43.726813
# 50%        48.765690
# 75%        54.528055
# max       135.980000
# Name: AVERAGE_NIC, dtype: float64
# ## Cluster 2 ORANGE Viagra and others
# count    1882.000000
# mean       11.811450
# std         7.344857
# min         0.688750
# 25%         7.004654
# 50%        10.701667
# 75%        15.166244
# max        97.110000
# Name: AVERAGE_NIC, dtype: float64
# ## Cluster 3 RED Oral hypoglycaemics
# count    1798.000000
# mean        3.358839
# std         1.243718
# min         0.781538
# 25%         2.507304
# 50%         3.120263
# 75%         3.958056
# max        15.699286
# Name: AVERAGE_NIC, dtype: float64
# ## Cluster 3 RED Metformin
# count    1798.000000
# mean        4.339789
# std         1.347811
# min         0.990000
# 25%         3.377748
# 50%         4.076644
# 75%         5.036250
# max        12.148200
# Name: AVERAGE_NIC, dtype: float64
# ## Cluster 3 RED Gliptins
# count    1797.000000
# mean       39.640738
# std        10.886288
# min         8.737174
# 25%        32.486424
# 50%        38.048129
# 75%        45.406210
# max       108.742500
# Name: AVERAGE_NIC, dtype: float64
# ## Cluster 3 RED Insulin1
# count    1795.000000
# mean       46.366118
# std         9.244331
# min         7.709457
# 25%        40.518750
# 50%        45.073600
# 75%        50.562994
# max       148.210000
# Name: AVERAGE_NIC, dtype: float64
# ## Cluster 3 RED Insulin
# count    1796.000000
# mean       49.911871
# std         8.395744
# min         9.759366
# 25%        44.377369
# 50%        48.987192
# 75%        54.095357
# max       112.637500
# Name: AVERAGE_NIC, dtype: float64
# ## Cluster 3 RED Viagra and others
# count    1795.000000
# mean       12.077582
# std         6.380012
# min         0.710000
# 25%         7.729165
# 50%        11.170000
# 75%        15.297639
# max        69.345714
# Name: AVERAGE_NIC, dtype: float64
