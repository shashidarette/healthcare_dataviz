# %%
## This notebooks deals the patient list size data exploration##
# User can choose the area code and compare its mean with overall UK mean patient list size #

# %%
import pandas as pd
patient_list = pd.read_csv('Patient_List_Size_Dec17.csv', sep=',', encoding = "ISO-8859-1")

# %%
patient_list.columns
# Out:
# Index(['Regional Office Name', 'Regional Office Code', 'Area Team Name',
#        'Area Team Code', 'PCO Name', 'PCO Code', 'Practice Name',
#        'Practice Code', 'Male 0-4', 'Female 0-4', 'Male 5-14', 'Female 5-14',
#        'Male 15-24', 'Female 15-24', 'Male 25-34', 'Female 25-34',
#        'Male 35-44', 'Female 35-44', 'Male 45-54', 'Female 45-54',
#        'Male 55-64', 'Female 55-64', 'Male 65-74', 'Female 65-74', 'Male 75+',
#        'Female 75+'],
#       dtype='object')

# %%
patient_list.head()
# Out:
#   Regional Office Name Regional Office Code               Area Team Name  \
# 0               LONDON                  Y56  NORTH EAST LONDON AREA TEAM
# 1               LONDON                  Y56  NORTH EAST LONDON AREA TEAM
# 2               LONDON                  Y56  NORTH EAST LONDON AREA TEAM
# 3               LONDON                  Y56  NORTH EAST LONDON AREA TEAM
# 4               LONDON                  Y56  NORTH EAST LONDON AREA TEAM
#
#   Area Team Code                PCO Name PCO Code  \
# 0            Q61  BARKING & DAGENHAM CCG    07L00
# 1            Q61  BARKING & DAGENHAM CCG    07L00
# 2            Q61  BARKING & DAGENHAM CCG    07L00
# 3            Q61  BARKING & DAGENHAM CCG    07L00
# 4            Q61  BARKING & DAGENHAM CCG    07L00
#
#                     Practice Name Practice Code  Male 0-4  Female 0-4  \
# 0            ABBEY MEDICAL CENTRE        F82625       305         278
# 1  BARKING MEDICAL GROUP PRACTICE        F82018       479         420
# 2    CHILD & FAMILY HEALTH CENTRE        Y02583       636         655
# 3                       DR A ARIF        F86040       181         172
# 4          DR A MOGHAL'S PRACTICE        F82677       245         280
#
#       ...      Male 35-44  Female 35-44  Male 45-54  Female 45-54  Male 55-64  \
# 0     ...             713           521         499           392         275
# 1     ...             838           863         709           732         531
# 2     ...            1325          1052         574           415         207
# 3     ...             392           357         347           219         185
# 4     ...             465           508         450           464         242
#
#    Female 55-64  Male 65-74  Female 65-74  Male 75+  Female 75+
# 0           188         134           120        74          86
# 1           471         273           321       214         356
# 2           204          55            68        21          51
# 3           162          88            99        67          84
# 4           237         149           147        94         143
#
# [5 rows x 26 columns]

# %%
# patient_list[['Male 0-4'],['Female 0-4'], ['Male 5-14'], ['Female 5-14'],
#       ['Male 15-24'], ['Female 15-24'], ['Male 25-34'], ['Female 25-34'],
#       ['Male 35-44'], ['Female 35-44'], ['Male 45-54'], ['Female 45-54'],
#       ['Male 55-64'], ['Female 55-64'], ['Male 65-74'], ['Female 65-74'], ['Male 75+'],
#       ['Female 75+']]
patient_list['TotalSize'] = patient_list['Male 0-4']+ patient_list['Female 0-4'] + patient_list ['Male 5-14']+ patient_list['Female 5-14']+patient_list['Male 15-24']+patient_list['Female 15-24']+ patient_list['Male 25-34']+patient_list['Female 25-34']+patient_list['Male 35-44']+ patient_list['Female 35-44']+ patient_list['Male 45-54']+ patient_list['Female 45-54']+ patient_list['Male 55-64']+ patient_list['Female 55-64']+ patient_list['Male 65-74']+ patient_list['Female 65-74']+ patient_list['Male 75+']+ patient_list['Female 75+']
patient_list['TotalSize'].describe()
# Out:
# count     7327.000000
# mean      8017.811928
# std       5120.968212
# min          1.000000
# 25%       4400.000000
# 50%       7115.000000
# 75%      10561.500000
# max      72151.000000
# Name: TotalSize, dtype: float64

# %%
patient_list.head()
# Out:
#   Regional Office Name Regional Office Code               Area Team Name  \
# 0               LONDON                  Y56  NORTH EAST LONDON AREA TEAM
# 1               LONDON                  Y56  NORTH EAST LONDON AREA TEAM
# 2               LONDON                  Y56  NORTH EAST LONDON AREA TEAM
# 3               LONDON                  Y56  NORTH EAST LONDON AREA TEAM
# 4               LONDON                  Y56  NORTH EAST LONDON AREA TEAM
#
#   Area Team Code                PCO Name PCO Code  \
# 0            Q61  BARKING & DAGENHAM CCG    07L00
# 1            Q61  BARKING & DAGENHAM CCG    07L00
# 2            Q61  BARKING & DAGENHAM CCG    07L00
# 3            Q61  BARKING & DAGENHAM CCG    07L00
# 4            Q61  BARKING & DAGENHAM CCG    07L00
#
#                     Practice Name Practice Code  Male 0-4  Female 0-4  \
# 0            ABBEY MEDICAL CENTRE        F82625       305         278
# 1  BARKING MEDICAL GROUP PRACTICE        F82018       479         420
# 2    CHILD & FAMILY HEALTH CENTRE        Y02583       636         655
# 3                       DR A ARIF        F86040       181         172
# 4          DR A MOGHAL'S PRACTICE        F82677       245         280
#
#       ...      Male 35-44  Female 35-44  Male 45-54  Female 45-54  Male 55-64  \
# 0     ...             713           521         499           392         275
# 1     ...             838           863         709           732         531
# 2     ...            1325          1052         574           415         207
# 3     ...             392           357         347           219         185
# 4     ...             465           508         450           464         242
#
#    Female 55-64  Male 65-74  Female 65-74  Male 75+  Female 75+
# 0           188         134           120        74          86
# 1           471         273           321       214         356
# 2           204          55            68        21          51
# 3           162          88            99        67          84
# 4           237         149           147        94         143
#
# [5 rows x 26 columns]

# %%
patient_list['Area Team Code'].unique()
# Out:
# array(['Q61', 'Q62', 'Q63', 'Q53', 'Q54', 'Q55', 'Q56', 'Q57', 'Q58',
#        'Q59', 'Q60', 'Q44', 'Q49', 'Q45', 'Q46', 'Q47', 'Q48', 'Q50',
#        'Q51', 'Q52', 'Q64', 'Q65', 'Q66', 'Q67', 'Q68', 'Q69', 'Q70'], dtype=object)

# %%
## SELECT AREA CODE FROM ABOVE
AreaCode = 'Q59'

# %%
# CREATE AND APPLY AREA FILTER BASED ON AREA CODE
AreaFilter = patient_list['Area Team Code'] == AreaCode
AreaPatientList = patient_list[AreaFilter]
AreaPatientList.describe()
# Out:
#          Male 0-4  Female 0-4    Male 5-14  Female 5-14   Male 15-24  \
# count  235.000000  235.000000   235.000000   235.000000   235.000000
# mean   223.893617  211.617021   477.540426   454.395745   522.395745
# std    143.911065  135.778942   298.828670   288.873928   716.004877
# min      0.000000    0.000000     0.000000     0.000000     4.000000
# 25%    113.000000  101.500000   264.000000   247.000000   241.000000
# 50%    205.000000  197.000000   419.000000   410.000000   389.000000
# 75%    302.500000  281.000000   626.000000   598.000000   582.000000
# max    996.000000  943.000000  1929.000000  1934.000000  7668.000000
#
#        Female 15-24   Male 25-34  Female 25-34   Male 35-44  Female 35-44  \
# count    235.000000   235.000000    235.000000   235.000000    235.000000
# mean     504.404255   528.229787    522.931915   500.629787    486.182979
# std      735.777589   402.864602    367.444053   325.004160    309.233966
# min        0.000000    11.000000      0.000000    11.000000      0.000000
# 25%      228.000000   264.000000    253.000000   267.000000    258.500000
# 50%      374.000000   426.000000    455.000000   423.000000    440.000000
# 75%      542.500000   670.500000    692.000000   649.500000    638.000000
# max     6291.000000  2993.000000   2938.000000  2098.000000   2106.000000
#
#         Male 45-54  Female 45-54   Male 55-64  Female 55-64   Male 65-74  \
# count   235.000000    235.000000   235.000000    235.000000   235.000000
# mean    571.148936    565.357447   497.004255    492.587234   430.161702
# std     364.481084    372.077271   324.825732    333.432837   319.891621
# min       2.000000      0.000000     0.000000      0.000000     0.000000
# 25%     299.000000    301.000000   269.000000    261.000000   212.500000
# 50%     511.000000    517.000000   459.000000    475.000000   377.000000
# 75%     741.000000    774.000000   660.000000    648.000000   579.500000
# max    2731.000000   2648.000000  2324.000000   2303.000000  2116.000000
#
#        Female 65-74     Male 75+   Female 75+
# count    235.000000   235.000000   235.000000
# mean     448.021277   305.425532   391.587234
# std      338.582824   233.142371   301.663514
# min        0.000000     0.000000     0.000000
# 25%      220.000000   135.000000   168.000000
# 50%      399.000000   266.000000   354.000000
# 75%      603.500000   422.000000   535.000000
# max     2169.000000  1386.000000  1855.000000

# %%
AreaMean = AreaPatientList.mean()
PatientListMean = patient_list.mean()

print(AreaMean)
print(PatientListMean)
# Out:
# Male 0-4        223.893617
# Female 0-4      211.617021
# Male 5-14       477.540426
# Female 5-14     454.395745
# Male 15-24      522.395745
# Female 15-24    504.404255
# Male 25-34      528.229787
# Female 25-34    522.931915
# Male 35-44      500.629787
# Female 35-44    486.182979
# Male 45-54      571.148936
# Female 45-54    565.357447
# Male 55-64      497.004255
# Female 55-64    492.587234
# Male 65-74      430.161702
# Female 65-74    448.021277
# Male 75+        305.425532
# Female 75+      391.587234
# dtype: float64
# Male 0-4        232.046267
# Female 0-4      220.624812
# Male 5-14       479.819435
# Female 5-14     457.144261
# Male 15-24      475.003139
# Female 15-24    475.892726
# Male 25-34      578.976798
# Female 25-34    583.293162
# Male 35-44      552.605432
# Female 35-44    521.837587
# Male 45-54      577.229835
# Female 45-54    550.462263
# Male 55-64      465.158046
# Female 55-64    457.781630
# Male 65-74      370.028115
# Female 65-74    392.611847
# Male 75+        267.308175
# Female 75+      359.988399
# dtype: float64

# %%
# Drop TotalSize if computed
#AreaMean = AreaMean.drop(['TotalSize'])
#PatientListMean = PatientListMean.drop(['TotalSize'])

# %%
#referred : https://matplotlib.org/gallery/statistics/barchart_demo.html
import numpy as np
import matplotlib.pyplot as plt

n_groups = len(AreaMean.index)

fig, ax = plt.subplots()

index = np.arange(n_groups)
bar_width = 0.35

opacity = 0.4
error_config = {'ecolor': '0.3'}


rects1 = ax.bar(index, AreaMean.values, bar_width,
                alpha=opacity, color='b',
                error_kw=error_config,
                label=AreaCode)

rects2 = ax.bar(index + bar_width, PatientListMean.values, bar_width,
                alpha=opacity, color='r',
                error_kw=error_config,
                label='UK')

ax.set_xlabel('Age group')
ax.set_ylabel('Participant size')
ax.set_title(AreaCode + ' vs UK')
ax.set_xticks(index + bar_width / 2)
ax.set_xticklabels(AreaMean.index.values, rotation=90)
ax.legend()

fig.tight_layout()
plt.show()

# %%
practiceCodeFilter = patient_list['Practice Code'] == 'C82005'
practice = patient_list[practiceCodeFilter]
#print(len(practice.columns))
ageGroupsData = practice[practice.columns[8:]]
ageGroupsData.values
# Out:
# array([[311, 317, 598, 626, 564, 505, 701, 743, 631, 626, 580, 677, 492,
#         492, 372, 398, 242, 362]], dtype=int64)

# %%
PracticeCode1 = 'C83079'
PracticeCode2 = 'C83633'

# Filters
practiceCodeFilter1 = patient_list['Practice Code'] == PracticeCode1
practiceCodeFilter2 = patient_list['Practice Code'] == PracticeCode2

practice1 = patient_list[practiceCodeFilter1]
practice2 = patient_list[practiceCodeFilter2]

# Drop TotalSize if computed
#practice1 = practice1.drop(['TotalSize'])
#practice2 = practice2.drop(['TotalSize'])

print(practice1[practice.columns[8:]].values[0])
print(practice2[practice.columns[8:]].values[0])
# Out:
# [146 146 256 268 236 247 371 416 294 325 297 309 266 291 216 233 124 141]
# [120  93 261 246 233 224 158 188 222 260 355 388 327 316 266 283 197 263]

# %%
# VIEW PRACTICE AGE GROUPS SIDE BY SIDE
#referred : https://matplotlib.org/gallery/statistics/barchart_demo.html

import numpy as np
import matplotlib.pyplot as plt

n_groups = 18

fig, ax = plt.subplots()

index = np.arange(n_groups)
bar_width = 0.35

opacity = 0.4
error_config = {'ecolor': '0.3'}


rects1 = ax.bar(index, practice1[practice.columns[8:]].values[0], bar_width,
                alpha=opacity, color='b',
                error_kw=error_config,
                label= PracticeCode1)

rects2 = ax.bar(index + bar_width, practice2[practice.columns[8:]].values[0], bar_width,
                alpha=opacity, color='r',
                error_kw=error_config,
                label= PracticeCode2)

#rects3 = ax.bar(index + bar_width * 2, AreaMean.values, bar_width,
#                alpha=opacity, color='g',
#                error_kw=error_config,
#                label= 'UK')

ax.set_xlabel('Age group')
ax.set_ylabel('Participant size')
ax.set_title(PracticeCode1 + ' vs ' + PracticeCode2) #  + ' vs ' + 'UK')
ax.set_xticks(index + bar_width)
ax.set_xticklabels(practice.columns[8:], rotation=90)
ax.legend()

fig.tight_layout()
plt.show()

# %%
# Fixing random state for reproducibility
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0, patient_list['TotalSize'].count(), 1.0)
y = patient_list['TotalSize']
s = patient_list['TotalSize'].count() * 10 + patient_list['TotalSize'].max() + 100

plt.scatter(x, y)
plt.xlabel("Practice Index")
plt.ylabel("Patient List Size")
plt.show()

# %%
#patient_list['TotalSize']
import seaborn as sns
sns.set(color_codes=True)
sns.distplot(patient_list['TotalSize']);
plt.show()

# %%
AreaCodeFilter = patient_list['Area Team Code'] == 'Q59'
AreaCodePractices = patient_list[AreaCodeFilter]
AreaCodePractices.head()
# Out:
#               Regional Office Name Regional Office Code  \
# 3066  MIDLANDS AND EAST OF ENGLAND                  Y55
# 3067  MIDLANDS AND EAST OF ENGLAND                  Y55
# 3068  MIDLANDS AND EAST OF ENGLAND                  Y55
# 3069  MIDLANDS AND EAST OF ENGLAND                  Y55
# 3070  MIDLANDS AND EAST OF ENGLAND                  Y55
#
#                                Area Team Name Area Team Code  \
# 3066  LEICESTERSHIRE & LINCOLNSHIRE AREA TEAM            Q59
# 3067  LEICESTERSHIRE & LINCOLNSHIRE AREA TEAM            Q59
# 3068  LEICESTERSHIRE & LINCOLNSHIRE AREA TEAM            Q59
# 3069  LEICESTERSHIRE & LINCOLNSHIRE AREA TEAM            Q59
# 3070  LEICESTERSHIRE & LINCOLNSHIRE AREA TEAM            Q59
#
#                                  PCO Name PCO Code  \
# 3066  EAST LEICESTERSHIRE AND RUTLAND CCG    03W00
# 3067  EAST LEICESTERSHIRE AND RUTLAND CCG    03W00
# 3068  EAST LEICESTERSHIRE AND RUTLAND CCG    03W00
# 3069  EAST LEICESTERSHIRE AND RUTLAND CCG    03W00
# 3070  EAST LEICESTERSHIRE AND RUTLAND CCG    03W00
#
#                     Practice Name Practice Code  Male 0-4  Female 0-4  \
# 3066              BUSHLOE SURGERY        C82013       311         291
# 3067  COUNTESTHORPE HEALTH CENTRE        C82002       302         285
# 3068              COUNTY PRACTICE        C82042       318         293
# 3069     EMPINGHAM MEDICAL CENTRE        C82044       166         159
# 3070       ENDERBY MEDICAL CENTRE        C82631       248         215
#
#         ...      Female 35-44  Male 45-54  Female 45-54  Male 55-64  \
# 3066    ...               636         736           745         685
# 3067    ...               654         773           808         708
# 3068    ...               720         897           890         759
# 3069    ...               396         453           562         463
# 3070    ...               453         468           490         369
#
#       Female 55-64  Male 65-74  Female 65-74  Male 75+  Female 75+  TotalSize
# 3066           716         611           751       509         643      10808
# 3067           718         651           705       403         499      10630
# 3068           794         729           773       509         623      11904
# 3069           469         462           512       308         355       6469
# 3070           336         248           225       128         165       6243
#
# [5 rows x 27 columns]

# %%
# Fixing random state for reproducibility
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0, AreaCodePractices['TotalSize'].count(), 1.0)
y = AreaCodePractices['TotalSize']
s = AreaCodePractices['TotalSize'].count() * 10 + AreaCodePractices['TotalSize'].max() + 100

plt.scatter(x, y)
plt.xlabel("Practice Index")
plt.ylabel("Patient List Size")
plt.show()

# %%
AreaCodePractices.describe()
# Out:
#          Male 0-4  Female 0-4    Male 5-14  Female 5-14   Male 15-24  \
# count  235.000000  235.000000   235.000000   235.000000   235.000000
# mean   223.893617  211.617021   477.540426   454.395745   522.395745
# std    143.911065  135.778942   298.828670   288.873928   716.004877
# min      0.000000    0.000000     0.000000     0.000000     4.000000
# 25%    113.000000  101.500000   264.000000   247.000000   241.000000
# 50%    205.000000  197.000000   419.000000   410.000000   389.000000
# 75%    302.500000  281.000000   626.000000   598.000000   582.000000
# max    996.000000  943.000000  1929.000000  1934.000000  7668.000000
#
#        Female 15-24   Male 25-34  Female 25-34   Male 35-44  Female 35-44  \
# count    235.000000   235.000000    235.000000   235.000000    235.000000
# mean     504.404255   528.229787    522.931915   500.629787    486.182979
# std      735.777589   402.864602    367.444053   325.004160    309.233966
# min        0.000000    11.000000      0.000000    11.000000      0.000000
# 25%      228.000000   264.000000    253.000000   267.000000    258.500000
# 50%      374.000000   426.000000    455.000000   423.000000    440.000000
# 75%      542.500000   670.500000    692.000000   649.500000    638.000000
# max     6291.000000  2993.000000   2938.000000  2098.000000   2106.000000
#
#         Male 45-54  Female 45-54   Male 55-64  Female 55-64   Male 65-74  \
# count   235.000000    235.000000   235.000000    235.000000   235.000000
# mean    571.148936    565.357447   497.004255    492.587234   430.161702
# std     364.481084    372.077271   324.825732    333.432837   319.891621
# min       2.000000      0.000000     0.000000      0.000000     0.000000
# 25%     299.000000    301.000000   269.000000    261.000000   212.500000
# 50%     511.000000    517.000000   459.000000    475.000000   377.000000
# 75%     741.000000    774.000000   660.000000    648.000000   579.500000
# max    2731.000000   2648.000000  2324.000000   2303.000000  2116.000000
#
#        Female 65-74     Male 75+   Female 75+     TotalSize
# count    235.000000   235.000000   235.000000    235.000000
# mean     448.021277   305.425532   391.587234   8133.514894
# std      338.582824   233.142371   301.663514   5100.812031
# min        0.000000     0.000000     0.000000     47.000000
# 25%      220.000000   135.000000   168.000000   4255.500000
# 50%      399.000000   266.000000   354.000000   7252.000000
# 75%      603.500000   422.000000   535.000000  10682.000000
# max     2169.000000  1386.000000  1855.000000  35566.000000

# %%
import seaborn as sns
sns.set(color_codes=True)
sns.distplot(AreaCodePractices['TotalSize']);
plt.show()

# %%
AreaCodePractices.to_csv("Q59_PatientListSizes.csv", sep=',')
